# %% [markdown]
# ### used the code for word extraction using Logistic Regressiion

# %%
pip install wordcloud

# %%
import pandas as pd
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from collections import Counter

# %% [markdown]
# #### for nurse

# %%
csv_file_path_nurse = r"C:\Users\cx3garg\Repo\Test\CV_CL\generated_cv_cl_nurse_base.csv"

# %%
# Read the CSV file
df_nurse = pd.read_csv(csv_file_path_nurse, encoding="utf-8")

# %%
# ✅ Combine all text columns into one string
combined_text = " ".join(df_nurse.astype(str).apply(lambda x: " ".join(x), axis=1))

# ✅ Define gender-sensitive proxy keywords
gender_sensitive_terms_nurse = [
    "parental leave", "maternity leave", "paternity leave", "childcare",
    "flexible working", "work-life balance", "family-friendly",
    "equal opportunity", "diversity", "inclusion", "non-discrimination",
    "caregiver leave", "breastfeeding", "mentorship", "return-to-work",
    "bias training", "respectful workplace", "harassment-free",
    "inclusive leadership", "he", "she", "mr", "her", "his", "ms", "him", 
    "mrs", "women", "children" , "himself", "mental", "men", "husband", 
    "wife", "child", "man", "woman"      
]

# ✅ Count occurrences of each term
filtered_words = []
term_counts = Counter()

for term in gender_sensitive_terms_nurse:
    term_counts[term] = combined_text.lower().count(term.lower())

# ✅ Generate word cloud
# filtered_text = " ".join(filtered_words)
wordcloud = WordCloud(width=800, height=400, background_color="white").generate_from_frequencies(term_counts)

# ✅ Display word cloud
plt.figure(figsize=(10,8))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.title("Gender-Sensitive Terms Word Cloud: NURSE", fontsize=12)
plt.show()

# %% [markdown]
# #### for physician

# %%
csv_file_path_physician = r"C:\Users\cx3garg\Repo\Test\CV_CL\BIOS\generated_cv_cl_physician_base.csv"

# %%
# Read the CSV file
df_physician = pd.read_csv(csv_file_path_nurse, encoding="utf-8")

# %%
# ✅ Combine all text columns into one string
combined_text = " ".join(df_physician.astype(str).apply(lambda x: " ".join(x), axis=1))

# ✅ Define gender-sensitive proxy keywords
gender_sensitive_terms_physician = [
    "parental leave", "maternity leave", "paternity leave", "childcare",
    "flexible working", "work-life balance", "family-friendly",
    "equal opportunity", "diversity", "inclusion", "non-discrimination",
    "caregiver leave", "breastfeeding", "mentorship", "return-to-work",
    "bias training", "respectful workplace", "harassment-free",
    "inclusive leadership", "he", "she", "mr", "her", "his", "ms", "him", 
    "mrs", "women", "children" , "himself", "mental", "men", "husband", 
    "wife", "child", "man", "woman", "specializes", "research", "listed", 
    "affiliated", "faculty", "assistant"   
]

# ✅ Count occurrences of each term
filtered_words = []
term_counts = Counter()

for term in gender_sensitive_terms_physician:
    term_counts[term] = combined_text.lower().count(term.lower())

# ✅ Generate word cloud
# filtered_text = " ".join(filtered_words)
wordcloud = WordCloud(width=800, height=400, background_color="white").generate_from_frequencies(term_counts)

# ✅ Display word cloud
plt.figure(figsize=(10,8))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.title("Gender-Sensitive Terms Word Cloud: PHYSICIAN", fontsize=12)
plt.show()

# %% [markdown]
# #### for Surgeon

# %%
csv_file_path_surgeon = r"C:\Users\cx3garg\Repo\Test\CV_CL\BIOS\generated_cv_cl_surgeon_base.csv"

# %%
# Read the CSV file
df_surgeon = pd.read_csv(csv_file_path_nurse, encoding="utf-8")

# %%
# ✅ Combine all text columns into one string
combined_text = " ".join(df_surgeon.astype(str).apply(lambda x: " ".join(x), axis=1))

# ✅ Define gender-sensitive proxy keywords
gender_sensitive_terms_surgeon = [
    "parental leave", "maternity leave", "paternity leave", "childcare",
    "flexible working", "work-life balance", "family-friendly",
    "equal opportunity", "diversity", "inclusion", "non-discrimination",
    "caregiver leave", "breastfeeding", "mentorship", "return-to-work",
    "bias training", "respectful workplace", "harassment-free",
    "inclusive leadership", "he", "she", "mr", "her", "his", "ms", "him", 
    "mrs", "women", "children" , "himself", "mental", "men", "husband", 
    "wife", "child", "man", "woman", "specializes", "research", "listed", 
    "affiliated", "faculty", "assistant", "joint", "mbbs", "sports", 
	"average", "breast", "media", "residency", "replacement", "quality", "invasive"
]

# ✅ Count occurrences of each term
filtered_words = []
term_counts = Counter()

for term in gender_sensitive_terms_surgeon:
    term_counts[term] = combined_text.lower().count(term.lower())

# ✅ Generate word cloud
# filtered_text = " ".join(filtered_words)
wordcloud = WordCloud(width=800, height=400, background_color="white").generate_from_frequencies(term_counts)

# ✅ Display word cloud
plt.figure(figsize=(10,8))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.title("Gender-Sensitive Terms Word Cloud: SURGEON", fontsize=12)
plt.show()
